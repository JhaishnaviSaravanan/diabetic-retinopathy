# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.4 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.3 MB/s eta 0:00:000:00:0100:01
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="/kaggle/input/diabetic-retinopathy-with-stages/DR/data.yaml" epochs=100 imgsz=640 batch=16
# Out:
# ...
# Ultralytics 8.3.174 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo task=detect mode=val model="/kaggle/working/runs/detect/train/weights/best.pt" data="/kaggle/input/diabetic-retinopathy-with-stages/DR/data.yaml"
# Out:
# Ultralytics 8.3.174 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 38.4±2.9 MB/s, size: 19.2 KB)
# val: Scanning /kaggle/input/diabetic-retinopathy-with-stages/DR/valid/labels...
# WARNING ⚠️ val: Cache directory /kaggle/input/diabetic-retinopathy-with-stages/DR/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all        183        568      0.488      0.342      0.344      0.123
# ...

# %%
# !yolo task=detect mode=predict model="/kaggle/working/runs/detect/train/weights/best.pt" conf=0.30 source="/kaggle/input/diabetic-retinopathy-with-stages/DR/test/images/1-104-_png.rf.09e5cd1da542011b0be378455b6e9638.jpg"
# Out:
# Ultralytics 8.3.174 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /kaggle/input/diabetic-retinopathy-with-stages/DR/test/images/1-104-_png.rf.09e5cd1da542011b0be378455b6e9638.jpg: 640x640 2 Mild NPDRs, 6.4ms
# Speed: 6.0ms preprocess, 6.4ms inference, 158.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display
import os

pred_dir = "/kaggle/working/runs/detect/predict"
pred_image = os.path.join(pred_dir, os.listdir(pred_dir)[0])

display(Image(filename=pred_image))

# %%
# !zip -r working_dir.zip /kaggle/working/runs
# Out:
# updating: kaggle/working/runs/ (stored 0%)
# updating: kaggle/working/runs/detect/ (stored 0%)
# updating: kaggle/working/runs/detect/predict/ (stored 0%)
# updating: kaggle/working/runs/detect/predict/1-104-_png.rf.09e5cd1da542011b0be378455b6e9638.jpg (deflated 7%)
# updating: kaggle/working/runs/detect/train/ (stored 0%)
# updating: kaggle/working/runs/detect/train/train_batch3691.jpg (deflated 13%)
# updating: kaggle/working/runs/detect/train/val_batch0_pred.jpg (deflated 17%)
# updating: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 26%)
# updating: kaggle/working/runs/detect/train/train_batch1.jpg (deflated 11%)
# updating: kaggle/working/runs/detect/train/args.yaml (deflated 52%)
# updating: kaggle/working/runs/detect/train/train_batch3690.jpg (deflated 16%)
# updating: kaggle/working/runs/detect/train/BoxF1_curve.png (deflated 11%)
# updating: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 21%)
# ...
